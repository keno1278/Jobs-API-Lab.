# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Collecting Job Data Using APIs**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab, you will be able to:

# %% [markdown]
# *   Collect job data using Jobs API
# *   Store the collected data into an excel spreadsheet.

# %% [markdown]
# ><strong>Note: Before starting with the assignment make sure to read all the instructions and then move ahead with the coding part.</strong>

# %% [markdown]
# #### Instructions

# %% [markdown]
# To run the actual lab, firstly you need to click on the [Jobs_API](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/Jobs_API.ipynb) notebook link. The file contains flask code which is required to run the Jobs API data.
#
# Now, to run the code in the file that opens up follow the below steps.
#
# Step1: Download the file.
#
# Step2: Upload the file into your current Jupyter environment using the upload button in your Jupyter interface. Ensure that the file is in the same folder as your working .ipynb file.
#
# Step 2: If working in a local Jupyter environment, use the "Upload" button in your Jupyter interface to upload the Jobs_API notebook into the same folder as your current .ipynb file.
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/Upload.PNG">
#
# Step3:  Open the Jobs_API notebook, and run all the cells to start the Flask application. Once the server is running, you can access the API from the URL provided in the notebook.
#
# If you want to learn more about flask, which is optional, you can click on this link [here](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/FLASK_API.md.html).
#
# Once you run the flask code, you can start with your assignment.

# %% [markdown]
# ## Dataset Used in this Assignment
#
# The dataset used in this lab comes from the following source: https://www.kaggle.com/promptcloud/jobs-on-naukricom under the under a **Public Domain license**.
#
# > Note: We are using a modified subset of that dataset for the lab, so to follow the lab instructions successfully please use the dataset provided with the lab, rather than the dataset from the original source.
#
# The original dataset is a csv. We have converted the csv to json as per the requirement of the lab.

# %% [markdown]
# ## Warm-Up Exercise

# %% [markdown]
# Before you attempt the actual lab, here is a fully solved warmup exercise that will help you to learn how to access an API.

# %% [markdown]
# Using an API, let us find out who currently are on the International Space Station (ISS).<br> The API at [http://api.open-notify.org/astros.json](http://api.open-notify.org/astros.json?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ) gives us the information of astronauts currently on ISS in json format.<br>
# You can read more about this API at [http://open-notify.org/Open-Notify-API/People-In-Space/](http://open-notify.org/Open-Notify-API/People-In-Space?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)

# %%
import requests # you need this module to make an API call
import pandas as pd

# %%
api_url = "http://api.open-notify.org/astros.json" # this url gives use the astronaut data

# %%
response = requests.get(api_url) # Call the API using the get method and store the
                                # output of the API call in a variable called response.

# %%
if response.ok:             # if all is well() no errors, no network timeouts)
    data = response.json()  # store the result in json format in a variable called data
                            # the variable data is of type dictionary.

# %%
print(data)   # print the data just to check the output or for debugging
# Out:
# {'people': [{'craft': 'ISS', 'name': 'Oleg Kononenko'}, {'craft': 'ISS', 'name': 'Nikolai Chub'}, {'craft': 'ISS', 'name': 'Tracy Caldwell Dyson'}, {'craft': 'ISS', 'name': 'Matthew Dominick'}, {'craft': 'ISS', 'name': 'Michael Barratt'}, {'craft': 'ISS', 'name': 'Jeanette Epps'}, {'craft': 'ISS', 'name': 'Alexander Grebenkin'}, {'craft': 'ISS', 'name': 'Butch Wilmore'}, {'craft': 'ISS', 'name': 'Sunita Williams'}, {'craft': 'Tiangong', 'name': 'Li Guangsu'}, {'craft': 'Tiangong', 'name': 'Li Cong'}, {'craft': 'Tiangong', 'name': 'Ye Guangfu'}], 'number': 12, 'message': 'success'}

# %% [markdown]
# Print the number of astronauts currently on ISS.

# %%
print(data.get('number'))
# Out:
# 12

# %% [markdown]
# Print the names of the astronauts currently on ISS.

# %%
astronauts = data.get('people')
print("There are {} astronauts on ISS".format(len(astronauts)))
print("And their names are :")
for astronaut in astronauts:
    print(astronaut.get('name'))
# Out:
# There are 12 astronauts on ISS
# And their names are :
# Oleg Kononenko
# Nikolai Chub
# Tracy Caldwell Dyson
# Matthew Dominick
# Michael Barratt
# Jeanette Epps
# Alexander Grebenkin
# Butch Wilmore
# Sunita Williams
# Li Guangsu
# Li Cong
# Ye Guangfu

# %% [markdown]
# Hope the warmup was helpful. Good luck with your next lab!

# %% [markdown]
# ## Lab: Collect Jobs Data using Jobs API

# %% [markdown]
# ### Objective: Determine the number of jobs currently open for various technologies  and for various locations

# %% [markdown]
# Collect the number of job postings for the following locations using the API:
#
# * Los Angeles
# * New York
# * San Francisco
# * Washington DC
# * Seattle
# * Austin
# * Detroit

# %%
#Import required libraries
import pandas as pd
import json

# %% [markdown]
# https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/jobs.json#### Write a function to get the number of jobs for the Python technology.<br>
# > Note: While using the lab you need to pass the **payload** information for the **params** attribute in the form of **key** **value** pairs.
#   Refer the ungraded **rest api lab** in the course **Python for Data Science, AI & Development**  <a href="https://www.coursera.org/learn/python-for-applied-data-science-ai/ungradedLti/P6sW8/hands-on-lab-access-rest-apis-request-http?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01">link</a>
#
#  ##### The keys in the json are
#  * Job Title
#
#  * Job Experience Required
#
#  * Key Skills
#
#  * Role Category
#
#  * Location
#
#  * Functional Area
#
#  * Industry
#
#  * Role
#
# You can also view  the json file contents  from the following <a href = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/jobs.json">json</a> URL.

# %%
import requests

api_url = "http://127.0.0.1:5000/data"


def get_number_of_jobs_T(technology):
    response = requests.get(api_url, params={"Job Title": technology})
    data = response.json()  # this is a list of job dicts
    number_of_jobs = len(data)  # count how many jobs were returned
    return technology, number_of_jobs

# %% [markdown]
# Calling the function for Python and checking if it works.

# %%
get_number_of_jobs_T("Python")
# Out:
# ('Python', 191)

# %% [markdown]
# #### Write a function to find number of jobs in US for a location of your choice

# %%
def get_number_of_jobs_L(location):
    response = requests.get(api_url, params={"Location": location})
    data = response.json()
    number_of_jobs = len(data)  # count how many match
    return location, number_of_jobs

# %% [markdown]
# Call the function for Los Angeles and check if it is working.

# %%
#your code goes here

get_number_of_jobs_L("Los Angeles")
# Out:
# ('Los Angeles', 640)

# %% [markdown]
# ### Store the results in an excel file

# %% [markdown]
# Call the API for all the given technologies above and write the results in an excel spreadsheet.

# %% [markdown]
# If you do not know how create excel file using python, double click here for **hints**.
#
# <!--
#
# from openpyxl import Workbook        # import Workbook class from module openpyxl
# wb=Workbook()                        # create a workbook object
# ws=wb.active                         # use the active worksheet
# ws.append(['Country','Continent'])   # add a row with two columns 'Country' and 'Continent'
# ws.append(['Eygpt','Africa'])        # add a row with two columns 'Egypt' and 'Africa'
# ws.append(['India','Asia'])          # add another row
# ws.append(['France','Europe'])       # add another row
# wb.save("countries.xlsx")            # save the workbook into a file called countries.xlsx
#
#
# -->

# %% [markdown]
# Create a python list of all technologies for which you need to find the number of jobs postings.

# %%
#your code goes here

technologies = ["Python", "Java", "C++", "JavaScript", "SQL"]

# %% [markdown]
# Import libraries required to create excel spreadsheet

# %%
# your code goes here
# !pip install openpyxl
from openpyxl import Workbook
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.3-py2.py3-none-any.whl (251 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.3/251.3 kB 32.0 MB/s eta 0:00:00
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.3

# %% [markdown]
# Create a workbook and select the active worksheet

# %%
# your code goes here

wb = Workbook()
ws = wb.active
ws.title = "Job Postings"
ws.append(["Technology", "Number of Jobs"])  # Header row

# %% [markdown]
# Find the number of jobs postings for each of the technology in the above list.
# Write the technology name and the number of jobs postings into the excel spreadsheet.

# %%
for tech in technologies:
    tech_name, job_count = get_number_of_jobs_T(tech)
    ws.append([tech_name, job_count])
# Out:
# Status code: 200
# Response text: [{"Functional Area":"IT Software - Application Programming , Maintenance","Id":156,"Industry":"Recruitment, Staffing","Job Experience Required":"1 - 3 yrs","Job Title":"Python Developer","Key Skills":"Python","Location":"Los Angeles","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":217,"Industry":"IT-Software, Software Services","Job Experience Required":"0 - 1 yrs","Job Title":"Python Developer","Key Skills":"Debugging| Troubleshooting|Python| Interpersonal skills| OOPS| Programming| developer","Location":"Los Angeles","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - DBA , Datawarehousing","Id":412,"Industry":"IT-Software, Software Services","Job Experience Required":"3 - 5 yrs","Job Title":"Senior Business Analyst - Sql/Python","Key Skills":"data analysis| vba| macros| advanced excel| oracle sql| google analytics| business analysis|Python| data mining| business analyst","Location":"New York","Role":"Business Analyst","Role Category":"System Design/Implementation/ERP/CRM"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":448,"Industry":"IT-Software, Software Services","Job Experience Required":"3 - 6 yrs","Job Title":"Python Manager - IIT/ IIM/ DSE/ ISI","Key Skills":"Microstrategy| Business Intelligence| Cognos| Business Objects| Tableau| AWS|Python| SQL","Location":"Boston","Role":"IT/Networking-Manager","Role Category":"Admin/Maintenance/Security/Datawarehousing"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":577,"Industry":"IT-Software, Software Services","Job Experience Required":"2 - 6 yrs","Job Title":"Senior Software Engineer/ Team Lead -Python/ Django","Key Skills":"Python| MySQL| Redis| NoSQL| Django| MongoDB| Postgresql| Data Structures| AWS| Algorithms","Location":"New York","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":579,"Industry":"IT-Software, Software Services","Job Experience Required":"1 - 4 yrs","Job Title":"Software Engineer - Node.js/ Java/Python","Key Skills":"Java| C++| C| Ruby on Rails| Django| Node.js| Algorithm| Data Structure|Python","Location":"Washington DC","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":713,"Industry":"IT-Software, Software Services","Job Experience Required":"3 - 6 yrs","Job Title":"Tcs Florida is Hiring forPython Developers","Key Skills":"L3 Protocols| L2|Python| IP Networking| Microservices","Location":"San Francisco","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Other","Id":744,"Industry":"IT-Software, Software Services","Job Experience Required":"1 - 3 yrs","Job Title":"Python/django Developer","Key Skills":"front end|Python| django| backend| mysql| javascript| D3.Js","Location":"Seattle","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":805,"Industry":"IT-Software / Software Services","Job Experience Required":"4 - 9 Years","Job Title":"Python Scripting Professional","Key Skills":"Python|django|unix shell scripting|web technologies|web development|machine learning|application development|agile methodology","Location":"Austin","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":845,"Industry":"IT-Software / Software Services","Job Experience Required":"6 - 11 Years","Job Title":"Devops -Python :oracle-bangalore","Key Skills":"git|oracle|sed|awk|build|linux|jenkins|hudson|unix|Python","Location":"Seattle","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Applicatio ...
#
# Status code: 200
# Response text: [{"Functional Area":"IT Software - DBA , Datawarehousing","Id":24,"Industry":"IT-Software, Software Services","Job Experience Required":"6 - 8 yrs","Job Title":"Back End Java Developer - Restful Services/soap","Key Skills":"Java EE| JMS| Core Java| JUnit| Weblogic| HTML| JPA| JSON| SOAP| SQL","Location":"Washington DC","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":32,"Industry":"IT-Software, Software Services","Job Experience Required":"6 - 8 yrs","Job Title":"US Based Financial Company Looking For Java API Engineers For HYD","Key Skills":"Java| java api| Banking| j2ee| API| finance| core java| microservices","Location":"Washington DC","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":93,"Industry":"IT-Software, Software Services","Job Experience Required":"1 - 2 yrs","Job Title":"Java Developer","Key Skills":"CSS| Singleton| XML| Javascript| JDBC| Struts| JSON| HTML| Spring Boot| JQuery","Location":"Los Angeles","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":170,"Industry":"IT-Software / Software Services","Job Experience Required":"2 - 4 Years","Job Title":"Java Enterprise Edition","Key Skills":"Oracle|Core Java|Business process|Outsourcing|Operations|spring integration|J2Ee|Spring framework|JEE|Manager Technology","Location":"Los Angeles","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":199,"Industry":"Banking, Financial Services, Broking","Job Experience Required":"1 - 5 yrs","Job Title":"Java Software Engineer","Key Skills":"Linux| Agile|Python| Computer science| Coding| Fixed income| Machine learning| Asset management| JIRA| Financial services","Location":"Los Angeles","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":216,"Industry":"IT-Software, Software Services","Job Experience Required":"5 - 10 yrs","Job Title":"Java Developer - Spring/ Hibernate","Key Skills":"Java| Webservices| Spring| Hibernate| System Design| ESB| SQL| Spring Boot| Javascript","Location":"Los Angeles","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":227,"Industry":"IT-Software, Software Services","Job Experience Required":"3 - 5 yrs","Job Title":"Senior Java Developer- Urgently Required by Arizona IT Company","Key Skills":"java| mongodb| Hibernate| spring| jms","Location":"Los Angeles","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":229,"Industry":"IT-Software, Software Services","Job Experience Required":"5 - 10 yrs","Job Title":"Senior Software Engineer - UI Development - Javascript/angularjs","Key Skills":"software development life cycle| css| html5| ui development| design patterns| svn| software engineering| angularjs| javascript","Location":"Los Angeles","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":271,"Industry":"IT-Software / Software Services","Job Experience Required":"6 - 11 Years","Job Title":"Java Full Stack \u2013 Technical Lead, Senior Engineer","Key Skills":"Java|Angular JS|Hibernate|Core Java|Technical Leader|Technical|Javascript|Spring|JQuery|JS framework","Location":"Los Angeles","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":301,"Industry":"IT-Software, Software Services","Job Experience Required":"4 - 7 yrs","Job Title":"Java Full Stack Developer ...
#
# Status code: 200
# Response text: [{"Functional Area":"IT Software - Application Programming , Maintenance","Id":28,"Industry":"IT-Software, Software Services","Job Experience Required":"4 - 9 yrs","Job Title":"Software Engineer - C++ Development - Ooad/oops","Key Skills":"C#| Java| OOP| C++| Multithreading| UML| OOAD| OOPS| .Net| debugging","Location":"Washington DC","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":1190,"Industry":"IT-Software, Software Services","Job Experience Required":"2 - 4 yrs","Job Title":"C++ Developer","Key Skills":"TCP| c++| programmer| IP| developer","Location":"Austin","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - ERP , CRM","Id":1714,"Industry":"Retail, Wholesale","Job Experience Required":"2 - 7 yrs","Job Title":"C++ Developer - Spatial Customer Success","Key Skills":"C++| Application development| Data structures| Debugging| CAD| Social media| Computer science| Life sciences| Geometry","Location":"Houston","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":1739,"Industry":"IT-Software / Software Services","Job Experience Required":"0 - 5 Years","Job Title":"Software Engineer, :NO Resume Campaign C++,Python","Key Skills":"Java|Oracle SQL|HTML|C++|Software Engineering|Python|Unix|MVC|Html5|Spring","Location":"Houston","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Other","Id":2119,"Industry":"IT-Software, Software Services","Job Experience Required":"2 - 5 yrs","Job Title":"Urgent Opening For C++ Developer in Florida","Key Skills":"C++| Multithreading| Algorithms| Linux| Data Structures| STL| boost","Location":"Detroit","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":2847,"Industry":"IT-Software, Software Services","Job Experience Required":"3 - 7 yrs","Job Title":"C++ Developer - LTE Protocol - Telecom/ Networking Domain","Key Skills":"Telecom| C++| Protocols| Networking| L2| L3| SCTP| LTE","Location":"New York","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":3409,"Industry":"IT-Software, Software Services","Job Experience Required":"3 - 6 yrs","Job Title":"C++ QT - New Jersey","Key Skills":"QT| C| C++","Location":"Baltimore","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":3578,"Industry":"IT-Software, Software Services","Job Experience Required":"4 - 9 yrs","Job Title":"C,C++ Developer Drive","Key Skills":"Networking| Data structures| Firewall| Middleware| DNS| DHCP| IPV6| Embedded Linux| NAT| Networking protocols","Location":"Baltimore","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":3644,"Industry":"IT-Software, Software Services","Job Experience Required":"3 - 8 yrs","Job Title":"Immediate Opening ForPython with C++ - CMML 5 Company - Bangalore -","Key Skills":"Python| c++","Location":"Baltimore","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":3675,"Industry":"IT-Software, Software Services","Job Experience Required":"13 - 18 yrs","Job Title":"Senior Engineering Manager - C++ (enterprise Software)","Key Skills":"enterprise software| C++| product development| product engineering| application development","Location":"Baltimore","Role":"Head/VP/GM-Technology(IT)/CTO","Role Category":"Senior Management"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":3699,"Industry":"IT-Software, Software Services","Job Exp ...
#
# Status code: 200
# Response text: [{"Functional Area":"IT Software - Application Programming , Maintenance","Id":1858,"Industry":"IT-Software, Software Services","Job Experience Required":"1 - 4 yrs","Job Title":"PHP Developer with Extensive JavaScript Experience(work from Anywhere)","Key Skills":"rest| node.js| java| xml| design patterns| oops| linux| json| php| mysql| javascript","Location":"Houston","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":3420,"Industry":"IT-Software, Software Services","Job Experience Required":"5 - 8 yrs","Job Title":"SharePoint 2010, 2013, JASON/CSOM, JavaScript, ASPDotnet, C#","Key Skills":"c++| C| design| MySQL| JavaScript| HTML","Location":"Baltimore","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":5206,"Industry":"IT-Software, Software Services","Job Experience Required":"2 - 6 yrs","Job Title":"core java and JavaScript","Key Skills":"Core Java| Javascript| Programming","Location":"New Orleons","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":5265,"Industry":"IT-Software, Software Services","Job Experience Required":"3 - 8 yrs","Job Title":"Angular+ JavaScript Developer Mega Walk-in Drive","Key Skills":"front end| css| html5| ui development| bootstrap| web designing| javascript| jquery","Location":"New Orleons","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - eCommerce , Internet Technologies","Id":5915,"Industry":"IT-Software, Software Services","Job Experience Required":"6 - 11 yrs","Job Title":"Lead Full Stack Developer - React+redux+node - JavaScript Stack","Key Skills":"react.js| node.js| sockets| mvc","Location":"Washington DC","Role":"Team Lead/Technical Lead","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":6353,"Industry":"IT-Software, Software Services","Job Experience Required":"2 - 5 yrs","Job Title":"Ruby on Rails Developer - Html/ CSS/ JavaScript","Key Skills":"CSS| GIT| Web Technologies| Javascript| Database| HTML| JSON| Web Application Development| JQuery| Ruby","Location":"New York","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":7385,"Industry":"IT-Software, Software Services","Job Experience Required":"2 - 3 yrs","Job Title":"Full Stack Developer ( Reactjs/ Nodejs/ Angularjs/ JavaScript )","Key Skills":"rest|Python| web application| javascript| react.js| node.js| git| graphic designing| web technologies| php| api| angularjs","Location":"New York","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":7494,"Industry":"IT-Software, Software Services","Job Experience Required":"1 - 3 yrs","Job Title":"Looking for Dynamic || Frontend / JavaScript Developer","Key Skills":"javascript| front end| web technologies| application development| react.js| jscript| data structures| algorithms| algo| node.js| jQuery| DOM| Mean Stack","Location":"Seattle","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":9190,"Industry":"IT-Software, Software Services","Job Experience Required":"4 - 6 yrs","Job Title":"Full Stack JavaScript Developer - React.js","Key Skills":"Laravel| Javascript| React.Js| Web Application Development| PHP| MVC| GIT| Front End| OOP| Design Patterns| web development","Location":"New York","Role":"Software Developer","Role Category":"Programming & Design"},{"Functional Area":"IT Software - Application Programming , Maintenance","Id":10128,"Industry":"IT-Software, Software Services","Job Experience Required":" ...
#
# Status code: 500
# Response text: <!doctype html>
# <html lang=en>
# <title>500 Internal Server Error</title>
# <h1>Internal Server Error</h1>
# <p>The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.</p>
#
# Error fetching data for: SQL

# %% [markdown]
# Save into an excel spreadsheet named **job-postings.xlsx**.

# %%
#your code goes here

wb.save("job-postings.xlsx")

# %% [markdown]
# #### In the similar way, you can try for below given technologies and results  can be stored in an excel sheet.

# %% [markdown]
# Collect the number of job postings for the following languages using the API:
#
# *   C
# *   C#
# *   C++
# *   Java
# *   JavaScript
# *   Python
# *   Scala
# *   Oracle
# *   SQL Server
# *   MySQL Server
# *   PostgreSQL
# *   MongoDB

# %%
# your code goes here

# %% [markdown]
# ## Authors

# %% [markdown]
# Ayushi Jain

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja
#
# Lakshmi Holla
#
# Malika

# %% [markdown]
# Copyright © IBM Corporation.

# %% [markdown]
# <!--## Change Log

# %% [markdown]
# <!--| Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2022-01-19        | 0.3     | Lakshmi Holla        | Added changes in the markdown      |
# | 2021-06-25        | 0.2     | Malika            | Updated GitHub job json link       |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |--!>
